# %% [markdown]
# # Reinforcement Learning
#
# **Grid World environment with DQN**
#
# \- Vaibhav Rao
#   50375332
#
# \- Kunal Beniwal
#   50381672

# %%
! pip install gym
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)

# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym
from gym import spaces
from keras.models import Sequential
from keras.layers import *
from tensorflow.keras.optimizers import Adam
from collections import deque
import random
import time
import math

# %%
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from keras import backend as K
config = tf.compat.v1.ConfigProto( device_count = {'GPU': 1 , 'CPU': 16} )
sess = tf.compat.v1.Session(config=config) 
K.set_session(sess)

# %% [markdown]
# #### Grid World Environment

# %%
class GridEnvironment(gym.Env):
    metadata = { 'render.modes': [] }
    
    def __init__(self):
        self.observation_space = spaces.Discrete(16)
        self.action_space = spaces.Discrete(4)
        self.max_timesteps = 30
        self.state_map = state_map = {(0,0):0, (0,1):1,(0,2):2,(0,3):3,(1,0):4,(1,1):5,(1,2):6,(1,3):7,(2,0):8,(2,1):9,(2,2):10,(2,3):11,\
                          (3,0):12,(3,1):13,(3,2):14,(3,3):15}
        
    def reset(self):
        self.timestep = 0
        self.agent_pos = [0, 0]
        self.goal_pos = [3, 3]
        self.trap = [0, 3]
        self.food = [1,1]
        self.state = np.zeros((4,4))
        self.state[tuple(self.agent_pos)] = 1
        self.state[tuple(self.goal_pos)] = 0.5
        self.state[tuple(self.trap)] = 0.3
        self.state[tuple(self.food)] = 0.1
        observation = self.agent_pos[0]*4 + self.agent_pos[1]
        return observation
    
    def step(self, action):
        self.prev_state = list(self.agent_pos)
        # Move DOWN
        if action == 0:
          self.agent_pos[0] += 1
        # Move UP
        if action == 1:
          self.agent_pos[0] -= 1
        # Move Right
        if action == 2:
          self.agent_pos[1] += 1
        # Move Left
        if action == 3:
          self.agent_pos[1] -= 1
          
        self.agent_pos = np.clip(self.agent_pos, 0, 3)
        self.state = np.zeros((4,4))
        self.state[tuple(self.agent_pos)] = 1
        self.state[tuple(self.goal_pos)] = 0.5
        self.state[tuple(self.trap)] = 0.3
        self.state[tuple(self.food)] = 0.1
        observation = self.state_map[(self.agent_pos[0],self.agent_pos[1])]
        
        reward = 0
        if (self.agent_pos == self.goal_pos).all():
          reward = 50
        if (self.agent_pos == self.trap).all():
          reward = -10
        if (self.agent_pos == self.food).all():
          reward = 15
        if (self.agent_pos == self.prev_state).all():
          reward = -2
        
        self.timestep += 1
        done = True if (self.timestep >= self.max_timesteps) or (self.agent_pos == self.goal_pos).all() else False
        info = {}

        return observation, reward, done, info

    # def step_stochastic(self, action):
    #     self.prev_state = list(self.agent_pos)
    #     self.same_pos_reward = True
    #     # Move DOWN (Stochastic with 0.1 probability of not moving)
    #     if action == 0:
    #       stoch_step = np.random.choice([1, 0], p=[0.9,0.1])
    #       self.agent_pos[0] += stoch_step
    #       if not stoch_step:
    #         self.same_pos_reward = False
    #     # Move UP
    #     if action == 1:
    #       self.agent_pos[0] -= 1
    #     # Move Right
    #     if action == 2:
    #       self.agent_pos[1] += 1
    #     # Move Left (Probability of not taking a left in this action = 0.3)
    #     if action == 3:
    #       stoch_step = np.random.choice([1, 0], p=[0.7,0.3])
    #       self.agent_pos[1] -= stoch_step
    #       if not stoch_step:
    #         self.same_pos_reward = False

    #     self.agent_pos = np.clip(self.agent_pos, 0, 3)
    #     self.state = np.zeros((4,4))
    #     self.state[tuple(self.agent_pos)] = 1
    #     self.state[tuple(self.goal_pos)] = 0.5
    #     self.state[tuple(self.trap)] = 0.3
    #     self.state[tuple(self.food)] = 0.1
    #     # observation = self.state.flatten()
    #     observation = self.agent_pos[0]*4 + self.agent_pos[1]
        
    #     reward = 0
    #     if (self.agent_pos == self.goal_pos).all():
    #       reward = 10
    #     if (self.agent_pos == self.trap).all():
    #       reward = -5
    #     if (self.agent_pos == self.food).all():
    #       reward = 2
    #     if (self.agent_pos == self.prev_state).all() and self.same_pos_reward:
    #       reward = -1
        
        
    #     self.timestep += 1
    #     done = True if self.timestep >= self.max_timesteps else False
    #     info = {}
        
    #     return observation, reward, done, info

    def render(self):
        plt.imshow(self.state)

    def run(self, agent):
      state = self.reset()
      self.R=0
      while True:            
        action = agent.act(state)
        nextState, reward, done, info = self.step(action)
        #if done and nextState!=15:
        #   reward -= 10
        edecay = agent.remember(state, action, reward, nextState, done)
        agent.replay(32)

        state = nextState
        self.R = self.R + reward

        if done:
            break
      return self.R,edecay

# %%
env = GridEnvironment()
obs = env.reset()
env.render()

# %% [markdown]
# #### DQN AGENT ON Grid World PART I

# %%
class Agent():
  def __init__(self, env):
    self.env = env
    self.observation_space = env.observation_space.n
    self.action_space = env.action_space.n
    self.lr = 0.0025
    self.model = self.buildModel()
    self.memory = deque(maxlen=1500)
    self.gamma = 0.95
    self.epsilon = 1.0
    print("IN INITTTT")
    self.test_states = [x for x in range(self.observation_space)]
    self.test_states = tf.keras.utils.to_categorical(self.test_states)

  def buildModel(self):
    model = Sequential()
    model.add(Dense(64, input_shape=(self.observation_space,), activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(self.action_space, activation='linear'))
    model.compile(loss='mse', optimizer=Adam(learning_rate=self.lr))
    return model

  def predictState(self, state):
    #print("State in predict", state)
    #print("Pred Output", self.model.predict(state))
    return self.model.predict(state)

  def act(self, state):
    if np.random.uniform(0,1) <= self.epsilon:
      return np.random.choice(self.action_space)
    else:
      return np.argmax(self.predictState(self.test_states[state].reshape(-1, self.observation_space)))

  def sample(self,n):
    n = min(n, len(self.memory))
    return random.sample(self.memory, n)

  def remember(self, state, action, reward, next_state, done):
    self.memory.append((state, action, reward, next_state, done))
    if ((self.epsilon > 0.01) and done):
        self.epsilon *= 0.9
    return self.epsilon
    

  def replay(self, batch_size):
    if len(self.memory) < batch_size:
      return
    sample_batch = random.sample(self.memory, batch_size)
    states = np.array([ item[0] for item in sample_batch ])
    next_states = np.array([ item[3] for item in sample_batch ])
    predictedStates = self.model.predict(self.test_states[states].reshape(-1, self.observation_space))
    predictedNextStates = self.model.predict(self.test_states[next_states].reshape(-1, self.observation_space))
    x = np.zeros((batch_size, self.observation_space))
    y = np.zeros((batch_size, self.action_space))
   
    for i, (state, action, reward, next_state, done) in enumerate(sample_batch):
      target = predictedStates[i]
      target[action] = reward
      if not done:
        target[action] = reward + self.gamma * np.amax(predictedNextStates[i])
      x[i] = state
      y[i] = target
    #print("calling fit")
    # Printing the Q-table every 250 episodes.
    #q_table = self.predictState(np.asarray(self.test_states).reshape(-1, self.observation_space))
    # for terminal_state in [2, 8, 9, 10, 15]:  # The list represents terminal states.
    # # Manually setting terminal states to zero as the neural network will
    # # generalize and produce non-zero q-values for even the terminal states.
    # q_table[terminal_state] = 0 
    #print(f'\nQ-Table after episodes:\n', q_table)

    self.model.fit(x, y, batch_size=batch_size, epochs=0, verbose=1)

# %%
env = GridEnvironment()

states  = env.observation_space.n
actions = env.action_space.n
agent = Agent(env)
reward = []
epsilon_decay = []
episodes=250
for i in range(episodes):
    r,e = env.run(agent)
    reward.append(r)
    epsilon_decay.append(e)
    print(f"Episode:{i+1} and Total reward for episode: {r}")
# Out:
# Episode:1 and Total reward for episode: -31
# Episode:2 and Total reward for episode: 72
# Episode:3 and Total reward for episode: 57
# Episode:4 and Total reward for episode: 35
# Episode:5 and Total reward for episode: 88
# Episode:6 and Total reward for episode: 63
# Episode:7 and Total reward for episode: 30
# Episode:8 and Total reward for episode: 56
# Episode:9 and Total reward for episode: 49
# Episode:10 and Total reward for episode: -3
# Episode:11 and Total reward for episode: 52
# Episode:12 and Total reward for episode: 11
# Episode:13 and Total reward for episode: -16
# Episode:14 and Total reward for episode: -21
# Episode:15 and Total reward for episode: 53
# Episode:16 and Total reward for episode: -2
# Episode:17 and Total reward for episode: -6
# Episode:18 and Total reward for episode: 13
# Episode:19 and Total reward for episode: -2
# Episode:20 and Total reward for episode: -14
# Episode:21 and Total reward for episode: 30
# Episode:22 and Total reward for episode: 11
# Episode:23 and Total reward for episode: 7
# Episode:24 and Total reward for episode: 15
# Episode:25 and Total reward for episode: -2
# Episode:26 and Total reward for episode: 0
# Episode:27 and Total reward for episode: 28
# Episode:28 and Total reward for episode: 11
# Episode:29 and Total reward for episode: 45
# Episode:30 and Total reward for episode: 0
# Episode:31 and Total reward for episode: -2
# Episode:32 and Total reward for episode: 15
# Episode:33 and Total reward for episode: -2
# Episode:34 and Total reward for episode: 15
# Episode:35 and Total reward for episode: 0
# Episode:36 and Total reward for episode: 0
# Episode:37 and Total reward for episode: 0
# Episode:38 and Total reward for episode: 0
# Episode:39 and Total reward for episode: -2
# Episode:40 and Total reward for episode: 0
# Episode:41 and Total reward for episode: 0
# Episode:42 and Total reward for episode: 0
# Episode:43 and Total reward for episode: 0
# Episode:44 and Total reward for episode: 0
# Episode:45 and Total reward for episode: 0
# Episode:46 and Total reward for episode: 15
# Episode:47 and Total reward for episode: 0
# Episode:48 and Total reward for episode: 0
# Episode:49 and Total reward for episode: 0
# Episode:50 and Total reward for episode: 0
# Episode:51 and Total reward for episode: 0
# Episode:52 and Total reward for episode: 0
# Episode:53 and Total reward for episode: 0
# Episode:54 and Total reward for episode: 0
# Episode:55 and Total reward for episode: 0
# Episode:56 and Total reward for episode: 0
# Episode:57 and Total reward for episode: 0
# Episode:58 and Total reward for episode: 0
# Episode:59 and Total reward for episode: 0
# Episode:60 and Total reward for episode: 0
# Episode:61 and Total reward for episode: 0
# Episode:62 and Total reward for episode: 0
# Episode:63 and Total reward for episode: 0
# Episode:64 and Total reward for episode: 0
# Episode:65 and Total reward for episode: 13
# Episode:66 and Total reward for episode: 15
# Episode:67 and Total reward for episode: 0
# Episode:68 and Total reward for episode: 0
# Episode:69 and Total reward for episode: 0
# Episode:70 and Total reward for episode: 0
# Episode:71 and Total reward for episode: 0
# Episode:72 and Total reward for episode: 0
# Episode:73 and Total reward for episode: 0
# Episode:74 and Total reward for episode: 0
# Episode:158 and Total reward for episode: 0
# Episode:159 and Total reward for episode: 0
# Episode:160 and Total reward for episode: 0
# Episode:161 and Total reward for episode: -2
# Episode:162 and Total reward for episode: 0
# Episode:163 and Total reward for episode: 0
# Episode:164 and Total reward for episode: 0
# Episode:165 and Total reward for episode: 0
# Episode:166 and Total reward for episode: 0
# Episode:167 and Total reward for episode: 0
# Episode:168 and Total reward for episode: -2
# Episode:169 and Total reward for episode: 0
# Episode:170 and Total reward for episode: 0
# Episode:171 and Total reward for episode: 0
# Episode:172 and Total reward for episode: 0
# Episode:173 and Total reward for episode: 0
# Episode:174 and Total reward for episode: 0
# Episode:175 and Total reward for episode: 0
# Episode:176 and Total reward for episode: 0
# Episode:177 and Total reward for episode: 15
# Episode:178 and Total reward for episode: 0
# Episode:179 and Total reward for episode: 0
# Episode:180 and Total reward for episode: 0

# %%
plt.plot([i+1 for i in range(0, episodes, 2)], reward[::2])
plt.show()
plt.plot([i+1 for i in range(0, episodes, 2)], epsilon_decay[::2])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7dae45875a65> in <module>()
# ----> 1 plt.plot([i+1 for i in range(0, episodes, 2)], reward[::2])
#       2 plt.show()
#       3 plt.plot([i+1 for i in range(0, episodes, 2)], epsilon_decay[::2])
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# #### Double DQN AGENT on Grid World (PART II)

# %%
class AgentDDQN():
  def __init__(self, env):
    self.env = env
    self.observation_space = env.observation_space.n
    self.action_space = env.action_space.n
    self.lr = 0.0025
    self.model = self.buildModel()
    self.target_model = self.buildModel()
    self.memory = deque(maxlen=1500)
    self.gamma = 0.95
    self.epsilon = 1.0
    self.test_states = [x for x in range(self.observation_space)]
    self.test_states = tf.keras.utils.to_categorical(self.test_states)

  def buildModel(self):
    model = Sequential()
    model.add(Dense(64, input_shape=(self.observation_space,), activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(self.action_space, activation='linear'))
    model.compile(loss='mse', optimizer=Adam(learning_rate=self.lr))
    return model

  def predictState(self, state):
    return self.model.predict(state)

  def update_target_model(self):
    self.target_model.set_weights(self.model.get_weights())

  def act(self, state):
    if np.random.uniform(0,1) <= self.epsilon:
      return np.random.choice(self.action_space)
    else:
      return np.argmax(self.predictState(self.test_states[state].reshape(-1, self.observation_space)))

  def sample(self,n):
    n = min(n, len(self.memory))
    return random.sample(self.memory, n)

  def remember(self, state, action, reward, next_state, done):
    self.memory.append((state, action, reward, next_state, done))
    if ((self.epsilon > 0.01) and done):
        self.epsilon *= 0.9
    return self.epsilon

  def replay(self, batch_size):
    if len(self.memory) < batch_size:
      return
    sample_batch = random.sample(self.memory, batch_size)
    states = np.array([ item[0] for item in sample_batch ])
    next_states = np.array([ item[3] for item in sample_batch ])

    target = self.model.predict(self.test_states[states].reshape(-1, self.observation_space))
    target_next = self.model.predict(self.test_states[next_states].reshape(-1, self.observation_space))
    target_val = self.target_model.predict(self.test_states[next_states].reshape(-1, self.observation_space))

    for i, (state, action, reward, next_state, done) in enumerate(sample_batch):
      target[i][action] = reward
      if not done:
        a = np.argmax(target_next[i])
        target[i][action] = reward + self.gamma * (target_val[i][a])

    self.model.fit(states, target, batch_size=batch_size, epochs=0, verbose=1)

# %%
env = GridEnvironment()

states  = env.observation_space.n
actions = env.action_space.n
agent = AgentDDQN(env)
reward = []
epsilon_decay = []
episodes=150
for i in range(episodes):
    r,e = env.run(agent)
    if i % 5 == 0:
      agent.update_target_model()
    reward.append(r)
    epsilon_decay.append(e)
    print(f"Episode:{i+1} and Total reward for episode: {r}")
# Out:
# Episode:1 and Total reward for episode: 30
# Episode:2 and Total reward for episode: 46
# Episode:3 and Total reward for episode: 21
# Episode:4 and Total reward for episode: -3
# Episode:5 and Total reward for episode: -7
# Episode:6 and Total reward for episode: 106
# Episode:7 and Total reward for episode: 38
# Episode:8 and Total reward for episode: -34
# Episode:9 and Total reward for episode: 65
# Episode:10 and Total reward for episode: -26
# Episode:11 and Total reward for episode: -26
# Episode:12 and Total reward for episode: 59
# Episode:13 and Total reward for episode: -26
# Episode:14 and Total reward for episode: -34
# Episode:15 and Total reward for episode: -38
# Episode:16 and Total reward for episode: -17
# Episode:17 and Total reward for episode: -2
# Episode:18 and Total reward for episode: -36
# Episode:19 and Total reward for episode: -40
# Episode:20 and Total reward for episode: -22
# Episode:21 and Total reward for episode: -18
# Episode:22 and Total reward for episode: 11
# Episode:23 and Total reward for episode: 30
# Episode:24 and Total reward for episode: -2
# Episode:25 and Total reward for episode: -54
# Episode:26 and Total reward for episode: -50
# Episode:27 and Total reward for episode: 0
# Episode:28 and Total reward for episode: -28
# Episode:29 and Total reward for episode: -30
# Episode:30 and Total reward for episode: -22
# Episode:31 and Total reward for episode: 0
# Episode:32 and Total reward for episode: 0
# Episode:33 and Total reward for episode: -10
# Episode:34 and Total reward for episode: 0
# Episode:35 and Total reward for episode: -38
# Episode:36 and Total reward for episode: 0
# Episode:37 and Total reward for episode: -46
# Episode:38 and Total reward for episode: 0
# Episode:39 and Total reward for episode: -22
# Episode:40 and Total reward for episode: 0
# Episode:41 and Total reward for episode: 0
# Episode:42 and Total reward for episode: 0
# Episode:43 and Total reward for episode: 0
# Episode:44 and Total reward for episode: -2
# Episode:45 and Total reward for episode: 0
# Episode:46 and Total reward for episode: 0
# Episode:47 and Total reward for episode: 0
# Episode:48 and Total reward for episode: 0
# Episode:49 and Total reward for episode: 0
# Episode:50 and Total reward for episode: 15
# Episode:51 and Total reward for episode: 0
# Episode:52 and Total reward for episode: 0
# Episode:53 and Total reward for episode: 0
# Episode:54 and Total reward for episode: 0
# Episode:55 and Total reward for episode: 0
# Episode:56 and Total reward for episode: -18
# Episode:57 and Total reward for episode: 0
# Episode:58 and Total reward for episode: 0
# Episode:59 and Total reward for episode: 0
# Episode:60 and Total reward for episode: 0
# Episode:61 and Total reward for episode: -6
# Episode:62 and Total reward for episode: -2
# Episode:63 and Total reward for episode: 0
# Episode:64 and Total reward for episode: 15
# Episode:65 and Total reward for episode: 0
# Episode:66 and Total reward for episode: 0
# Episode:67 and Total reward for episode: -28
# Episode:68 and Total reward for episode: 0
# Episode:69 and Total reward for episode: 0
# Episode:70 and Total reward for episode: 0
# Episode:71 and Total reward for episode: 0
# Episode:72 and Total reward for episode: 0
# Episode:73 and Total reward for episode: 0
# Episode:74 and Total reward for episode: 0
# Episode:75 and Total reward for episode: 0
# Episode:76 and Total reward for episode: 0
# Episode:77 and Total reward for episode: 0
# Episode:78 and Total reward for episode: 0
# Episode:79 and Total reward for episode: -48
# Episode:80 and Total reward for episode: 0
# Episode:81 and Total reward for episode: 0
# Episode:82 and Total reward for episode: 0
# Episode:83 and Total reward for episode: 0
# Episode:84 and Total reward for episode: 0
# Episode:85 and Total reward for episode: 0
# Episode:86 and Total reward for episode: 0
# Episode:87 and Total reward for episode: 15
# Episode:88 and Total reward for episode: 0
# Episode:89 and Total reward for episode: 0
# Episode:90 and Total reward for episode: 0
# Episode:91 and Total reward for episode: 0
# Episode:92 and Total reward for episode: 0
# Episode:93 and Total reward for episode: 0
# Episode:94 and Total reward for episode: 0
# Episode:95 and Total reward for episode: -2
# Episode:96 and Total reward for episode: 0
# Episode:97 and Total reward for episode: 0
# Episode:98 and Total reward for episode: 0
# Episode:99 and Total reward for episode: 0
# Episode:100 and Total reward for episode: 0
# Episode:101 and Total reward for episode: -2
# Episode:102 and Total reward for episode: 0
# Episode:103 and Total reward for episode: 0
# Episode:104 and Total reward for episode: 0
# Episode:105 and Total reward for episode: 0
# Episode:106 and Total reward for episode: 0
# Episode:107 and Total reward for episode: 0
# Episode:108 and Total reward for episode: 0
# Episode:109 and Total reward for episode: 0
# Episode:110 and Total reward for episode: 0
# Episode:111 and Total reward for episode: 0
# Episode:112 and Total reward for episode: 0
# Episode:113 and Total reward for episode: 0
# Episode:114 and Total reward for episode: -10
# Episode:115 and Total reward for episode: -10
# Episode:116 and Total reward for episode: 0
# Episode:117 and Total reward for episode: 0
# Episode:118 and Total reward for episode: 0
# Episode:119 and Total reward for episode: 0
# Episode:120 and Total reward for episode: 0
# Episode:121 and Total reward for episode: 0
# Episode:122 and Total reward for episode: 0
# Episode:123 and Total reward for episode: 0
# Episode:124 and Total reward for episode: 0
# Episode:125 and Total reward for episode: 0
# Episode:126 and Total reward for episode: 0
# Episode:127 and Total reward for episode: 0
# Episode:128 and Total reward for episode: -4
# Episode:129 and Total reward for episode: 0
# Episode:130 and Total reward for episode: -2
# Episode:131 and Total reward for episode: -50
# Episode:132 and Total reward for episode: 0
# Episode:133 and Total reward for episode: 0
# Episode:134 and Total reward for episode: 0
# Episode:135 and Total reward for episode: -8
# Episode:136 and Total reward for episode: 0
# Episode:137 and Total reward for episode: -2
# Episode:138 and Total reward for episode: 0
# Episode:139 and Total reward for episode: -48
# Episode:140 and Total reward for episode: -2
# Episode:141 and Total reward for episode: 0
# Episode:142 and Total reward for episode: -2
# Episode:143 and Total reward for episode: 0
# Episode:144 and Total reward for episode: 0
# Episode:145 and Total reward for episode: 0
# Episode:146 and Total reward for episode: 0
# Episode:147 and Total reward for episode: -50
# Episode:148 and Total reward for episode: 0
# Episode:149 and Total reward for episode: 0
# Episode:150 and Total reward for episode: 0

# %%
plt.plot([i+1 for i in range(0, episodes)], reward)
plt.show()
plt.plot([i+1 for i in range(0, episodes)], epsilon_decay)
plt.show()

# %% [markdown]
# #### DQN Agent on Cartpole (PART II)

# %%
class AgentCartpole():
  def __init__(self, env):
    self.env = env
    self.observation_space = env.env.observation_space.shape[0]
    self.action_space = env.env.action_space.n
    self.lr = 0.001
    self.model = self.buildModel()
    self.memory = deque(maxlen=5000)
    self.gamma = 0.95
    self.epsilon = 1.0

  def buildModel(self):
    model = Sequential()
    model.add(Dense(32, input_shape=(self.observation_space,), activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(self.action_space, activation='linear'))
    model.compile(loss='mse', optimizer=Adam(learning_rate=self.lr))
    return model

  def predictState(self, state):
    return self.model.predict(state.reshape(1, self.observation_space)).flatten()

  def act(self, state):
    if np.random.uniform(0,1) <= self.epsilon:
      return np.random.choice(self.action_space)
    else:
      return np.argmax(self.predictState(state))

  def sample(self,n):
    n = min(n, len(self.memory))
    return random.sample(self.memory, n)

  def remember(self, state, action, reward, next_state, done):
    self.memory.append((state, action, reward, next_state, done))
    if ((self.epsilon > 0.01) and done):
        self.epsilon *= 0.9
    return self.epsilon
    
  def replay(self, batch_size):
    if len(self.memory) < batch_size:
      return
    sample_batch = self.sample(batch_size)
    states = np.array([item[0] for item in sample_batch ])
    next_states = np.array([item[3] for item in sample_batch])

    predictedStates = self.model.predict(states)
    predictedNextStates = self.model.predict(next_states)

    #x = np.zeros((batch_size, self.observation_space))
    y = np.zeros((batch_size, self.action_space))

    for i, (state, action, reward, next_state, done) in enumerate(sample_batch):
      target = predictedStates[i]
      target[action] = reward
      if not done:
        target[action] = reward + self.gamma * np.amax(predictedNextStates[i])
      #x[i] = state
      y[i] = target

    self.model.fit(states, y, batch_size=batch_size, epochs=1, verbose=0)


class Environment:
    def __init__(self, env):
        self.env = gym.make(env)
        #self.R = None
    def run(self, agent):
        state = self.env.reset()
        #self.R=0
        self.score = 0
        while True:            
            action = agent.act(state)
            next_state, reward, done, info = self.env.step(action)
            reward = reward if not done or self.score == 499 else -100
            epsilon_decay=agent.remember(state, action, reward, next_state, done)
            agent.replay(256)    
            self.score += reward        
            state = next_state
            #self.R = self.R + reward
            if done:
              self.score = self.score if self.score == 500 else self.score + 100
              break
        return self.score,epsilon_decay

env = Environment('CartPole-v1') #Tried v1 with 64 neurons but in very slow training
#env = Environment('CartPole-v0')

agent = AgentCartpole(env)

reward=[]
epsilon_decay=[]
scores = []
episodes=2000
for i in range(episodes):
    s,e=env.run(agent)
    #reward.append(r)
    epsilon_decay.append(e)
    scores.append(s)
    if np.mean(scores[-min(10, len(scores)):]) > 490:
      print("Exiting training since score achieved")
      sys.exit()

    print(f"Episode:{i} and Total reward for episode: {s}")
# Out:
# Episode:0 and Total reward for episode: 13.0
# Episode:1 and Total reward for episode: 17.0
# Episode:2 and Total reward for episode: 11.0
# Episode:3 and Total reward for episode: 14.0
# Episode:4 and Total reward for episode: 20.0
# Episode:5 and Total reward for episode: 14.0
# Episode:6 and Total reward for episode: 11.0
# Episode:7 and Total reward for episode: 10.0
# Episode:8 and Total reward for episode: 15.0
# Episode:9 and Total reward for episode: 11.0
# Episode:10 and Total reward for episode: 9.0
# Episode:11 and Total reward for episode: 15.0
# Episode:12 and Total reward for episode: 8.0
# Episode:13 and Total reward for episode: 13.0
# Episode:14 and Total reward for episode: 18.0
# Episode:15 and Total reward for episode: 11.0
# Episode:16 and Total reward for episode: 9.0
# Episode:17 and Total reward for episode: 8.0
# Episode:18 and Total reward for episode: 11.0
# Episode:19 and Total reward for episode: 18.0
# Episode:20 and Total reward for episode: 8.0
# Episode:21 and Total reward for episode: 11.0
# Episode:22 and Total reward for episode: 8.0
# Episode:174 and Total reward for episode: 194.0

# %%
plt.plot([i+1 for i in range(0, episodes)], reward)
plt.show()    
plt.plot([i+1 for i in range(0, episodes)], epsilon_decay)
plt.show()

# %% [markdown]
# Take 5 steps with GREEDY LEARNT POLICY

# %%
for e in range(5):
  state = env.reset()
  done = False
  i = 0
  while not done:
    env.render()
    action = np.argmax(agent.predict(state))
    next_state, reward, done, _ = env.step(action)
    state = next_state
    i += 1
    if done:
      print("episode: {}/{}, score: {}".format(e, 5, i))
      break

# %% [markdown]
# #### DOUBLE DQN Agent ON Cartpole (Part II)

# %%
class AgentDDQNCartpole():
  def __init__(self, env):
    self.env = env
    self.observation_space = env.env.observation_space.shape[0]
    self.action_space = env.env.action_space.n
    self.lr = 0.001
    print("INIT CALLLEDDDDDDD")
    #Make 2 models for DDQN
    self.model = self.buildModel()
    self.target_model = self.buildModel()
    self.memory = deque(maxlen=5000)
    self.gamma = 0.95
    self.epsilon = 1.0

  def buildModel(self):
    model = Sequential()
    model.add(Dense(32, input_shape=(self.observation_space,), activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(self.action_space, activation='linear'))
    model.compile(loss='mse', optimizer=Adam(learning_rate=self.lr))
    return model

  def predictState(self, state):
    #print("State in pred state:", state)
    return self.model.predict(state.reshape(1, self.observation_space)).flatten()

  def act(self, state):
    if np.random.uniform(0,1) <= self.epsilon:
      return np.random.choice(self.action_space)
    else:
      return np.argmax(self.predictState(state))

  def sample(self,n):
    n = min(n, len(self.memory))
    return random.sample(self.memory, n)

  def update_target_model(self):
    self.target_model.set_weights(self.model.get_weights())

  def remember(self, state, action, reward, next_state, done):
    self.memory.append((state, action, reward, next_state, done))
    if ((self.epsilon > 0.01) and done):
        self.epsilon *= 0.9
    return self.epsilon
    
  def replay(self, batch_size):
    if len(self.memory) < batch_size:
      return
    sample_batch = self.sample(batch_size)
    states = np.array([item[0] for item in sample_batch ])
    next_states = np.array([item[3] for item in sample_batch ])

    target = self.model.predict(states)
    target_next = self.model.predict(next_states)
    target_val = self.target_model.predict(next_states)

    for i, (state, action, reward, next_state, done) in enumerate(sample_batch):
      target[i][action] = reward
      if not done:
        a = np.argmax(target_next[i])
        target[i][action] = reward + self.gamma * (target_val[i][a])

    self.model.fit(states, target, batch_size=batch_size, epochs=1, verbose=0)


class Environment:
    def __init__(self, env):
        self.env = gym.make(env)
        self.R = None
    def run(self, agent):
        state = self.env.reset()
        self.R=0

        while True:            
            action = agent.act(state)
            next_state, reward, done, info = self.env.step(action)
            print(reward)
            reward = reward if not done or self.score == 499 else -100
            epsilon_decay=agent.remember(state, action, reward, next_state, done)
            agent.replay(256)    
            self.score += reward       
            print(score) 
            state = next_state
            if done: # terminal state
              agent.update_target_model()
              break
        return self.score,epsilon_decay



env = Environment('CartPole-v1')
agent = AgentDDQNCartpole(env)

epsilon_decay=[]
scores = []
episodes=2000
for i in range(episodes):
    s,e=env.run(agent)
    epsilon_decay.append(e)
    scores.append(s)
    if np.mean(scores[-min(10, len(scores)):]) > 470:
      print("Exiting training since score achieved")
      sys.exit()

    print(f"Episode:{i} and Total reward for episode: {s}")

# %%
plt.plot([i+1 for i in range(0, episodes)], reward)
plt.show()    
plt.plot([i+1 for i in range(0, episodes)], epsilon_decay)
plt.show()
